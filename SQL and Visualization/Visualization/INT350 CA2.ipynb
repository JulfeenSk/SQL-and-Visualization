# %% [markdown]
# # INT350 CA2

# %% [markdown]
# 4. Take any dataset of your choice and perform outlier analysis using boxplots. Write the interpretation of the graph.

# %%
#Importing the necessary libraries
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading the dataset as pandas dataframe
data = pd.read_csv("data.csv")
data
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 615         609  LP002978  Female      No          0      Graduate
# 616         610  LP002979    Male     Yes         3+      Graduate
# 617         611  LP002983    Male     Yes          1      Graduate
# 618         612  LP002984    Male     Yes          2      Graduate
# 619         613  LP002990  Female      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No            58490                0.0         NaN
# ...

# %%
# To analyse columns in the dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         620 non-null    int64
#  1   Loan_ID            620 non-null    object
#  2   Gender             607 non-null    object
#  3   Married            617 non-null    object
#  4   Dependents         605 non-null    object
#  5   Education          620 non-null    object
#  6   Self_Employed      587 non-null    object
#  7   ApplicantIncome    620 non-null    int64
#  8   CoapplicantIncome  620 non-null    float64
#  9   LoanAmount         598 non-null    float64
#  10  Loan_Amount_Term   606 non-null    float64
#  11  Credit_History     569 non-null    float64
#  12  Property_Area      620 non-null    object
#  13  Loan_Status        620 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 67.9+ KB

# %%
# creating boxplot
fig, axes = plt.subplots(1, 2, figsize=(10, 4)) 

axes[0].boxplot(data['ApplicantIncome'])
axes[0].set_title("Boxplot of ApplicantIncome")

axes[1].boxplot(data['CoapplicantIncome'])
axes[1].set_title("Boxplot of CoapplicantIncome")

plt.show()

# %% [markdown]
# **Interpretation of the Boxplot**
#
# - The box in the middle represents the interquartile range (IQR), which contains the middle 50% of the data.
# - The line inside the box represents the median of the data.
# - The lines(whiskers) extend from the box to the smallest and largest values within 1.5 times the IQR. Data points beyond the lines are considered potential outliers.
# - Individual data points outside the lines are shown as individual points and are often considered outliers.
# - Outliers can be values that are significantly higher or lower than the majority of the data.
# - The boxplot helps to visually identify the spread and distribution of data, as well as the presence of outliers.

# %% [markdown]
# 5. Using any dataset of your choice perform bivariate analysis and interpret each graph –
#
# a) Line Charts
#
# b) Bar Graph
#
# c) Box plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset as pandas dataframe
df = pd.read_csv("data.csv")
df
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 615         609  LP002978  Female      No          0      Graduate
# 616         610  LP002979    Male     Yes         3+      Graduate
# 617         611  LP002983    Male     Yes          1      Graduate
# 618         612  LP002984    Male     Yes          2      Graduate
# 619         613  LP002990  Female      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No            58490                0.0         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 614 entries, 0 to 619
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         614 non-null    int64
#  1   Loan_ID            614 non-null    object
#  2   Gender             601 non-null    object
#  3   Married            611 non-null    object
#  4   Dependents         599 non-null    object
#  5   Education          614 non-null    object
#  6   Self_Employed      582 non-null    object
#  7   ApplicantIncome    614 non-null    int64
#  8   CoapplicantIncome  614 non-null    float64
#  9   LoanAmount         592 non-null    float64
#  10  Loan_Amount_Term   600 non-null    float64
#  11  Credit_History     564 non-null    float64
#  12  Property_Area      614 non-null    object
#  13  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 72.0+ KB

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# **a)LineCharts**

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4)) 

axes[0].plot(df['Loan_Amount_Term'], df['Credit_History'],color ='blue')
axes[0].set_xlabel('Loan Amount_Term')
axes[0].set_ylabel('Credit History')
axes[0].set_title('Line Chart of Loan Amount Term Over Credit History')

axes[1].plot(df['LoanAmount'], df['Credit_History'],color ='red')
axes[1].set_xlabel('Loan Amount')
axes[1].set_ylabel('Credit History')
axes[1].set_title('Line Chart of Loan Amount Over Credit History')



plt.show()

# %% [markdown]
# ### Interpretation
#
# **Line Chart of Loan Amount Term Over Credit History**
# - The blue Line CHart shows how Credit_history change over Loan_Amount_Term
# - It provides a visula representation of the trend in credit over amount term
# - Each point on the line chart corresponds to a data point in the dataset,where 'Loan_Amount_Term' values are on the x-axis, and   'Credit_History' values are on the y-axis.
#
# **Line Chart of Loan Amount Over Credit History**
#
# - The red Line chart shows how Credit_history chnage over Loan Amount
# - it Provides a visual representation of the trend in credit over loan amount-  - Each point on the line chart corresponds to a data point in the dataset
# - where 'LoanAmount' values are on the x-axis, and 'Credit_History' values are on the y-axis

# %% [markdown]
# **b)Bar Graphs**

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 8)) 

sns.barplot(data=df, x='Gender', y='ApplicantIncome', ax=axes[0], palette='Blues')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('ApplicantIncome')
axes[0].set_title('Bar Graph of  Gender vs ApplicantIncome')

sns.barplot(data=df, x='Married', y='LoanAmount', ax=axes[1], palette='Reds')
axes[1].set_xlabel('Married')
axes[1].set_ylabel('LoanAmount')
axes[1].set_title('Bar Graph of Married vs LoanAmount')

plt.show()

# %% [markdown]
# ### Interpretation
#
# **Bar Graph of  Gender vs ApplicantIncome**
#
# - The upper bar graph displays the relationship between 'Gender'and 'ApplicantIncome'
#
# - It uses the 'Blues' color palette for the bars, with different colors representing different genders
#
# - The height of each bar represents the average 'ApplicantIncome' for each gender category.
#
# - From this graph, you can observe the differences in average applicant income between different genders.
#
# **Bar Graph of Married vs LoanAmount**
#
# - The lower bar graph displays the relationship between 'Married'  and 'LoanAmount'
#
# - It uses the 'Reds' color palette for the bars, with different colors representing marital status ('Married' or 'Not Married')
#
# - The height of each bar represents the average 'LoanAmount' for each marital status category
#
# - This graph allows you to examine whether there's a significant difference in loan amounts between married and unmarried individuals

# %% [markdown]
# **c)Box plots**

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

sns.boxplot(data=df, x='Education', y='LoanAmount', ax=axes[0])
axes[0].set_xlabel('Education')
axes[0].set_ylabel('ApplicantIncome')
axes[0].set_title('Box Plot: Education vs LoanAmount')

sns.boxplot(data=df, x='Gender', y='LoanAmount', ax=axes[1])
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('LoanAmount')
axes[1].set_title('Box Plot: Gender vs LoanAmount')


sns.boxplot(data=df, x='Married', y='LoanAmount', ax=axes[2])
axes[2].set_xlabel('Married')
axes[2].set_ylabel('CoapplicantIncme')
axes[2].set_title('Box Plot: Married vs LoanAmount')
# Out:
# Text(0.5, 1.0, 'Box Plot: Married vs LoanAmount')

# %% [markdown]
# ### Interpretation
#
# - It describes the variation of LoanAmount accross various types in Eduaction , Gender , MArried column
# **Education vs. LoanAmount**
#
# - The top box plot displays the relationship between 'Education'  and 'LoanAmount'
# - The box plot provides a summary of the distribution of 'LoanAmount' for each education category ('Graduate' and 'Not Graduate' and 'graduate')
# - It shows the median, quartiles, and potential outliers in each category's loan amounts
#
# **Gender vs. LoanAmount**
#
# - The middle box plot displays the relationship between 'Gender' and 'LoanAmount'
# - It allows us to compare the distribution of loan amounts between different genders ('Male' and 'Female')
# - Similar to the previous box plot, it shows the summary statistics and potential outliers for loan amounts based on gender
#
# **Married vs. LoanAmount**
#
# - The bottom box plot shows the relationship between 'Married' and 'LoanAmount'
# - It helps us compare distribution of loan amounts between different marital status ('Married' or 'Not Married')
# - Like the other box plots, it presents the central tendency and spread of loan amounts for each marital status group

# %% [markdown]
# 6.Briefly discuss about Stacked Bar Graphs with an example

# %% [markdown]
# **Stacked Bar Graphs**
#
# - A stacked bar graph is a type of bar chart where multiple data series are stacked on top of each other, rather than being shown side by side.
# - It's used to visualize the composition of a whole by showing the contributions of different categories or subgroups to that whole.
# - Each bar in a stacked bar graph represents the total quantity of a variable, and the segments within the bar represent how that quantity is divided among different categories or subgroups
# - A stacked bar graph is a type of data visualization used to represent the composition of a whole by showing how different categories or subgroups contribute to that whole
# - The height of each segment within a bar indicates its contribution to the total

# %% [markdown]
# **Example in context with above dataset**

# %%
import numpy as np

pivot_df = df.pivot_table(values='ApplicantIncome', index='Gender', columns='Education', aggfunc=np.sum, fill_value=0)


fig, ax = plt.subplots(figsize=(10, 10))
pivot_df.plot(kind='bar', stacked=True, ax=ax, colormap='viridis')


ax.set_xlabel('Gender')
ax.set_ylabel('ApplicantIncome')
ax.set_title('Stacked Bar Graph: LoanAmount by Education and Gender')


ax.legend(title='Education')


plt.show()
